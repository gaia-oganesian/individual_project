# %%
# Install necessary dependencies for the project
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: beautifulsoup4 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (4.12.3)
# Requirement already satisfied: html5lib in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (1.1)
# Requirement already satisfied: langdetect in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: nltk in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: tweet-preprocessor in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: ekphrasis in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 8)) (0.5.4)
# Requirement already satisfied: wordcloud in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 9)) (1.9.3)
# Requirement already satisfied: MarkupSafe in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: mpmath in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 11)) (0.19)
# Requirement already satisfied: accelerate in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 12)) (0.27.2)
# Requirement already satisfied: sentence-transformers in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 13)) (2.5.1)
# Requirement already satisfied: config in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 14)) (0.5.1)
# Requirement already satisfied: chardet in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 15)) (5.2.0)
# Requirement already satisfied: matplotlib in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 17)) (3.9.0)
# Requirement already satisfied: scikit-learn in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: numpy in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 20)) (1.26.4)
# Requirement already satisfied: python-dotenv in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 21)) (1.0.1)
# Requirement already satisfied: openai in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 36)) (1.42.0)
# Requirement already satisfied: plotly in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 40)) (5.22.0)
# Requirement already satisfied: umap-learn in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 41)) (0.5.6)
# Requirement already satisfied: hdbscan in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 42)) (0.8.37)
# Requirement already satisfied: bertopic in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from -r ../requirements.txt (line 43)) (0.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas->-r ../requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas->-r ../requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from beautifulsoup4->-r ../requirements.txt (line 3)) (2.5)
# Requirement already satisfied: six>=1.9 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from html5lib->-r ../requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: webencodings in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from html5lib->-r ../requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: click in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from nltk->-r ../requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: joblib in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from nltk->-r ../requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from nltk->-r ../requirements.txt (line 6)) (2024.5.15)
# Requirement already satisfied: tqdm in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from nltk->-r ../requirements.txt (line 6)) (4.66.4)
# Requirement already satisfied: termcolor in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from ekphrasis->-r ../requirements.txt (line 8)) (2.4.0)
# Requirement already satisfied: colorama in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from ekphrasis->-r ../requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: ujson in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from ekphrasis->-r ../requirements.txt (line 8)) (5.10.0)
# Requirement already satisfied: ftfy in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from ekphrasis->-r ../requirements.txt (line 8)) (6.2.0)
# Requirement already satisfied: pillow in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from wordcloud->-r ../requirements.txt (line 9)) (10.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from accelerate->-r ../requirements.txt (line 12)) (24.1)
# Requirement already satisfied: psutil in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from accelerate->-r ../requirements.txt (line 12)) (5.9.8)
# Requirement already satisfied: pyyaml in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from accelerate->-r ../requirements.txt (line 12)) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from accelerate->-r ../requirements.txt (line 12)) (2.3.1)
# Requirement already satisfied: huggingface-hub in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from accelerate->-r ../requirements.txt (line 12)) (0.23.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from accelerate->-r ../requirements.txt (line 12)) (0.4.3)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from sentence-transformers->-r ../requirements.txt (line 13)) (4.44.2)
# Requirement already satisfied: scipy in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from sentence-transformers->-r ../requirements.txt (line 13)) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (3.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 19)) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from openai->-r ../requirements.txt (line 36)) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from openai->-r ../requirements.txt (line 36)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from openai->-r ../requirements.txt (line 36)) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from openai->-r ../requirements.txt (line 36)) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from openai->-r ../requirements.txt (line 36)) (2.8.2)
# Requirement already satisfied: sniffio in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from openai->-r ../requirements.txt (line 36)) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from openai->-r ../requirements.txt (line 36)) (4.12.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from plotly->-r ../requirements.txt (line 40)) (8.4.2)
# Requirement already satisfied: numba>=0.51.2 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from umap-learn->-r ../requirements.txt (line 41)) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from umap-learn->-r ../requirements.txt (line 41)) (0.5.13)
# Requirement already satisfied: cython<3,>=0.27 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from hdbscan->-r ../requirements.txt (line 42)) (0.29.37)
# Requirement already satisfied: idna>=2.8 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 36)) (3.7)
# Requirement already satisfied: certifi in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 36)) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 36)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 36)) (0.14.0)
# Requirement already satisfied: filelock in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from huggingface-hub->accelerate->-r ../requirements.txt (line 12)) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from huggingface-hub->accelerate->-r ../requirements.txt (line 12)) (2024.6.0)
# Requirement already satisfied: requests in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from huggingface-hub->accelerate->-r ../requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn->-r ../requirements.txt (line 41)) (0.43.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 36)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 36)) (2.20.1)
# Requirement already satisfied: sympy in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from torch>=1.10.0->accelerate->-r ../requirements.txt (line 12)) (1.12)
# Requirement already satisfied: networkx in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from torch>=1.10.0->accelerate->-r ../requirements.txt (line 12)) (3.3)
# Requirement already satisfied: jinja2 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from torch>=1.10.0->accelerate->-r ../requirements.txt (line 12)) (3.1.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers->-r ../requirements.txt (line 13)) (0.19.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from ftfy->ekphrasis->-r ../requirements.txt (line 8)) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate->-r ../requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gaia/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate->-r ../requirements.txt (line 12)) (2.2.1)

# %%
# Import necessary libraries and functions
import pandas as pd
from sklearn.utils import resample
from preprocessing import *
# Out:
# [nltk_data] Downloading package punkt to /Users/gaia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/gaia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Path to the data file
data_path = '../dataset/events.csv'  # Replace with the actual path to your data file
output_path = '../dataset/cleaned_events.csv'  # Output path for the cleaned data
balanced_output_path = '../dataset/balanced_events.csv'  # Output path for the balanced data

# %%
# Step 1: Load the data
all_events = pd.read_csv(data_path, encoding='ISO-8859-1', encoding_errors='replace')
print("Initial data shape:", all_events.shape)
# Out:
# Initial data shape: (18154, 31)

# %%
# Step 2: Clean the data
cleaned_events_df = load_and_clean_data(data_path)
print("Data shape after initial cleaning:", cleaned_events_df.shape)
# Out:
# Data shape after initial cleaning: (15697, 31)

# %%
# Step 3: Filter and process the data
cleaned_events_df = filter_and_process_data(cleaned_events_df)
print("Data shape after preprocessing:", cleaned_events_df.shape)
# Out:
# Data shape after preprocessing: (10128, 33)
# /Users/gaia/Desktop/gaia/individual_project/preprocessing/preprocessing.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
# Step 4: Process the data for clustering
cleaned_events_df = process_for_clustering(cleaned_events_df)
print("Data shape after clustering preparation:", cleaned_events_df.shape)
# Out:
# Data shape after clustering preparation: (10128, 37)

# %%
# Step 5: Apply balancing to top N categories
balanced_df = filter_top_categories_and_balance(cleaned_events_df, top_n=5)
print("Data shape after balancing:", balanced_df.shape)
# Out:
# Data shape after balancing: (2835, 38)
# /Users/gaia/Desktop/gaia/individual_project/preprocessing/preprocessing.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['category_label'] = filtered_df['categories'].map(category_mapping)

# %%
# Step 6: Save the cleaned data
save_cleaned_data(cleaned_events_df, output_path)
save_cleaned_data(balanced_df, balanced_output_path)
# Out:
# The cleaned data has been saved to ../dataset/cleaned_events.csv
# The cleaned data has been saved to ../dataset/balanced_events.csv

# %%
# Display the first few rows to verify
cleaned_events_df.head(35)
# Out:
#    thread_id page_id comment_id    user_id                username  \
# 1    4895638       0          1  1281314.0              Risty Moon
# 2    2679019       0          1    86907.0               needmoney
# 3    5252517       0          1  2794182.0             PorExchange
# 4    3311610       0          1  1904909.0                LusoCoin
# 8    5032135       0          1  1153662.0                jimsteel
# 9    5112064       0          1  2356569.0                BountyZZ
# 10   5041613       0          1  2021066.0             B21Official
# 11   2357581       0          1  1267364.0      etherflyerofficial
# 13   2457005       0          1  1280873.0               kimmanuel
# 14   2767794       0          1   527272.0                Wapinter
# 15   5155696       0          1  1253250.0                 ellcrys
# 16   3133489       0          1  1759102.0           iagonofficial
# 17   5146873       0          1  1271586.0               NashAmajh
# 18   3026753       0          1    51173.0                   mprep
# 20   5258276       0          1  2659640.0      icoininternational
# 21   2208912       0          1  1156446.0                 A-TOKEN
# 22   4712033       0          1  1272841.0             Greenwinter
# 23   3168266       0          1  1169768.0               one_world
# 25   2052496       0          1   911296.0                  Bdstar
# 26   5078719       0          1  1319477.0                Locotoni
# 28   4136665       0          1  2130676.0                   ABYOO
# 29   1957769       0          1   112240.0                   Sylon
# 30   5099122       0          1  1096278.0               authoreon
# 31   4806296       0          1  2239306.0              pixietoken
# 33   5321407       0          1  1052091.0  CryptopreneurBrainboss
# 35   5041530       0          1  2391010.0               ezcashico
# 36   5091398       0          1  2393389.0    Crypto Carabao Group
# 37   5145624       0          1  1176794.0               ChiNgadOr
# 38   4629807       0          1  1182014.0            SANDRA EVANS
# 40   5070864       0          1  2475126.0         VRExplosion.pro
# 41   5244557       0          1  1292097.0          MarquiseMuseum
# 43   5375222       0          1   567446.0                 my luck
# 44   2080731       0          1   350580.0             irfan_pak10
# 46   5122233       0          1  2287893.0               coinfunda
# 49   3243356       0          1  1764692.0                BitFence
#
#           post_time   replies    views  active                   categories  \
# 1   14/08/2018 18:21     210.0   4260.0  False                       Bounty
# 2   02/01/2018 16:08    6144.0  47325.0  False                       Bounty
# 3   01/06/2020 09:43       1.0     97.0  False                        Other
# 4   12/04/2018 22:45      13.0    379.0  False      Bounty(LowQuality), ICO
# 8   18/09/2018 15:09      13.0    415.0  False                       Bounty
# 9   20/02/2019 00:40    7662.0  52271.0  False                       Bounty
# 10  01/10/2018 13:33       5.0    471.0  False              Bounty, Airdrop
# 11  04/11/2017 15:01     131.0  15612.0  False                  Bounty, ICO
# 13  24/11/2017 21:28       2.0    211.0  False                        Other
# 14  16/01/2018 20:22      34.0   1166.0  False                       Bounty
# 15  18/06/2019 13:07    1182.0  10307.0  False                       Bounty
# 16  15/03/2018 23:18      45.0   1484.0  False                 ICO, Airdrop
# 17  24/05/2019 13:45    3427.0  35845.0  False                       Bounty
# 18  26/02/2018 19:46       0.0    111.0  False                        Moved
# 20  26/06/2020 16:40     242.0   6386.0  False         ICO, Airdrop, Bounty
# 21  26/09/2017 16:22      13.0    656.0  False                  Bounty, ICO
# 22  20/07/2018 14:45     101.0   1236.0  False                      Airdrop
# 23  20/03/2018 16:14      20.0    514.0  False  Bounty(LowQuality), Airdrop
# 25  29/07/2017 03:01     772.0  22256.0  False                       Bounty
# 26  01/12/2018 18:23       7.0    282.0  False                      Airdrop
# 28  22/05/2018 14:49       0.0    187.0  False      Bounty(LowQuality), ICO
# 29  08/06/2017 20:34    1418.0  62439.0  False                  Bounty, ICO
# 30  18/01/2019 13:41     103.0   2160.0  False              Bounty, Airdrop
# 31  02/08/2018 21:00       6.0    283.0  False  Bounty(LowQuality), Airdrop
# 33  03/03/2021 14:35     362.0   4109.0  False                       Bounty
# 35  01/10/2018 11:13       0.0    350.0  False                       Bounty
# 36  31/12/2018 05:39       0.0    115.0  False           Bounty(LowQuality)
# 37  21/05/2019 09:34       0.0    401.0  False           Bounty(LowQuality)
# 38  09/07/2018 12:53      78.0   1224.0  False                      Airdrop
# 40  17/11/2018 13:49      75.0   1167.0  False                      Airdrop
# 41  29/04/2020 16:04       3.0    271.0  False                        Other
# 43  03/12/2021 12:46       7.0    566.0  False                        Other
# 44  11/08/2017 17:38     248.0   8418.0  False                  Bounty, ICO
# 46  19/03/2019 11:51       3.0    471.0  False           Bounty(LowQuality)
# 49  02/04/2018 17:14      29.0    508.0  False                      Airdrop
#
#     ... participation_comment_count mixed_comment_count other_comment_count  \
# 1   ...                       135.0                 1.0                69.0
# 2   ...                      5350.0                29.0               721.0
# 3   ...                         0.0                 0.0                 0.0
# 4   ...                         0.0                 0.0                 0.0
# 8   ...                         0.0                 0.0                13.0
# 9   ...                      6931.0                57.0               502.0
# 10  ...                         0.0                 0.0                 3.0
# 11  ...                        78.0                 0.0                51.0
# 13  ...                         0.0                 0.0                 0.0
# 14  ...                         0.0                 0.0                27.0
# 15  ...                         NaN                 NaN                 NaN
# 16  ...                         0.0                 0.0                 0.0
# 17  ...                      3063.0                33.0                48.0
# 18  ...                         0.0                 0.0                 0.0
# 20  ...                         0.0                 0.0                 0.0
# 21  ...                         0.0                 0.0                11.0
# 22  ...                         0.0                 0.0                 0.0
# 23  ...                         0.0                 0.0                 0.0
# 25  ...                         2.0                 0.0               736.0
# 26  ...                         0.0                 0.0                 0.0
# 28  ...                         0.0                 0.0                 0.0
# 29  ...                         0.0                 0.0              1354.0
# 30  ...                        84.0                 2.0                 9.0
# 31  ...                         0.0                 0.0                 0.0
# 33  ...                       150.0                 6.0                 8.0
# 35  ...                         0.0                 0.0                 0.0
# 36  ...                         0.0                 0.0                 0.0
# 37  ...                         0.0                 0.0                 0.0
# 38  ...                         0.0                 0.0                 0.0
# 40  ...                         0.0                 0.0                 0.0
# 41  ...                         0.0                 0.0                 0.0
# 43  ...                         0.0                 0.0                 0.0
# 44  ...                         0.0                 0.0               240.0
# 46  ...                         0.0                 0.0                 0.0
# 49  ...                         0.0                 0.0                 0.0
#
#     author_comment_count                              processed_clean_title  \
# 1                    1.0                     Angenium Project Bounty Thread
# 2                   38.0               YOURBLOCK BOUNTY IS OVER IN TH WEEK
# 3                    0.0                          Campaign ProEX Magic Pool
# 4                    0.0                LusoCoin  reserved referral  Phase
# 8                    1.0                         ONLINEJURY FEEDBACK BOUNTY
# 9                    9.0                  DigitalBits An Economy Reimagined
# 10                   3.0        BLife Cryptocurrency Education Training App
# 11                   3.0          TCASH New Decentralized Exchange Platform
# 13                   0.0       I newbie I would like join Bounties program
# 14                   3.0                  NapoleonX Translation Paid In ETH
# 15                   NaN  ELLCRYS Decentralized Software Development K E...
# 16                   0.0                IAGON Amazing  USD Airdrop Everyone
# 17                   3.0            K WORTH CMA TOKEN REWARD  NO KYC  ENDED
# 18                   0.0  MOVED  FitsoCoin Available Join Now Massive Bonus
# 20                   0.0                     iCoin Airdrop USD ICOIN Tokens
# 21                   3.0  A TOKEN  ATKN  The first blockchain based Cryp...
# 22                   0.0  STREAMITY ETH Decentralized cryptocurrency exc...
# 23                   0.0       M Earth token first Earth Token Subscribers
# 25                  33.0    Hash Rush Game Signature  Translation Campaign
# 26                   0.0          NIA Ionia Airdrop  Up To NIA  mln KWK ETH
# 28                   0.0                             Retwet Coin conference
# 29                  63.0   Primalbase  Distributed Workspace Tech Community
# 30                   1.0                                            Chrypto
# 31                   0.0       Join Pixie Token  PXE Bounty  Airdrop Portal
# 33                   3.0  BitSport Telegram  Reddit Bounty day Budget   ...
# 35                   1.0                 EzCash A Blockchain CC Marketplace
# 36                   0.0                            Bisq PHP BTC BSQ bounty
# 37                   0.0      GRAYLL Trading simplified maximum daily prize
# 38                   0.0                                   Callisto Network
# 40                   0.0       Airdrop VRExplosion Join Telegram Earn upto
# 41                   0.0  Marquise  Museum debit card referall partnersh...
# 43                   0.0  Round Bitgesell  BGL  Silvio Treasures   Decem...
# 44                   9.0  uooMAG Decentralised digital magazine publishi...
# 46                   0.0  Elrond Bounty Program Content  Referral Social...
# 49                   0.0          BITFENCE REMOVE HACKERS FROM YOUR NETWORK
#
#                                    processed_post_tex  \
# 1      Angenium Bounty Campaign officially ended  ...
# 2      HELLO EVERYONE  TEAM HAS DECIDED TO END THE...
# 3   ProEXs new campaign ProEX Magic Pool online  J...
# 4      LUSO ICOBounty program       We reserved  a...
# 8      Y       JURYONLINE       THE PLACE FOR RESP...
# 9      This image longer available     Visit tinyp...
# 10     B ICO    ailable       AV ae     App Store ...
# 11     NOTE  TCASH Official Main Thread  TCASH Eth...
# 13  I new I understand much technical part     I w...
# 14     Our community present following platform   ...
# 15  To see Bounty Final Stakes Report  Click      ...
# 16     ANN post   BOUNTY  Phase   BOUNTY  Phase   ...
# 17        Democratic Decentralized Crypto ad marke...
# 18  This topic moved Trashcan        Onforum altco...
# 20      The accusation made iCoin falsely represen...
# 21     ATOKEN    Introduction    Some time ago  te...
# 22        We sure Asian market today hold promise ...
# 23         CONGRATULATION TO ALL EARTH SUPPORTERS ...
# 25        WEBSITE WHITEPAPER  BLOG  TWITTER  FACEB...
# 26     Hello     This IONIA       Ionia updated ho...
# 28  Ive retwitted article Global Coin Conference A...
# 29     Distributed Workspace    Tech Community    ...
# 30       Telegram Bounty  Telegram Community    AN...
# 31     This image longer available     Visit tinyp...
# 33     N r TOK BITSPORT BOUNTY       BFI  CAMPAIGN...
# 35  NOTE  Every participates must join EZCash offi...
# 36  Bounty exists        Someone already trade bis...
# 37     TELEGRAM BOUNTY GAME coming     Join Group ...
# 38     WEBSITE  WHITEPAPER  FACEBOOK  TWITTER REDD...
# 40     ANY AIRDROP CAMPAIGN QUESTIONS Telegram    ...
# 41  Referal link        This project offered brand...
# 43     V    Weekly Free Bitgesell Lotto     Gilvio...
# 44     UM        uooMAG Bounty Campaigns       Cou...
# 46  Referral     Rewarded point every friend invit...
# 49        WEBSITE        ANN        TWITTER       ...
#
#                                clean_title_tokens  \
# 1                           project bounty thread
# 2                                  bounty th week
# 3                             campaign magic pool
# 4                                  reserved phase
# 8                                 feedback bounty
# 9                                         economy
# 10                             education training
# 11                          new exchange platform
# 13                        would like join program
# 14                                    translation
# 15                       development k ell reward
# 16                       amazing airdrop everyone
# 17                           k worth token reward
# 18                   available join massive bonus
# 20                                        airdrop
# 21                        token first based index
# 22                                       exchange
# 23                        earth first earth token
# 25  hash rush game signature translation campaign
# 26                                        airdrop
# 28                                coin conference
# 29                     distributed tech community
# 30
# 31         join pixie token bounty airdrop portal
# 33               telegram bounty day budget token
# 35
# 36                                         bounty
# 37               trading simplified maximum daily
# 38                                        network
# 40                     airdrop join telegram earn
# 41         marquise museum debit card partnership
# 43                                          round
# 44                      digital magazine platform
# 46         bounty program content referral social
# 49                                 remove network
#
#                                       post_tex_tokens  \
# 1   bounty campaign officially ended please submit...
# 2   everyone team decided end bounty count haste l...
# 3   new campaign magic join roi information campai...
# 4   reserved available bounty amount bounty progra...
# 8   place responsible bounty powered platform k si...
# 9   image longer protocol layer designed help faci...
# 10  celebrate launch education training community ...
# 11  official main thread truly solid exchange powe...
# 13  new understand much technical would like enter...
# 14  community present following twitter medium sla...
# 15  see bounty final report click official launch ...
# 16  post bounty phase bounty phase bounty phase te...
# 17  democratic marketing company building ecosyste...
# 18             topic giveaway posting within specific
# 20  made falsely urge see accusation thread proof ...
# 21  time ago team looking new fi instrument like f...
# 22  sure market today promise project decided firs...
# 23  earth increase global awareness act preserve e...
# 25  twitter work hard every day develop mining gam...
# 26  automatic trading robot worth airdrop event wa...
# 28  article global coin conference next week chanc...
# 29  tech upon business model project office rental...
# 30  bounty telegram thread token sale affiliate pr...
# 31  image longer pixie token team announce launch ...
# 33  n r bounty campaign last day team campaign man...
# 35  note every must join official telegram group q...
# 36            bounty already trade prove claim bounty
# 37  bounty game group june th receive game credit ...
# 38  twitter ann thread medium mention telegram cha...
# 40  airdrop campaign twitter telegram ann worth re...
# 41  project branded token partnership exchange reg...
# 43  free weekly draw member eligible least merit m...
# 44  bounty token st th digital magazine platform s...
# 46  every friend invite join platform friend invit...
# 49  thank participation late airdrop bounty campai...
#
#                                  general_rules_tokens  \
# 1   week general join bounty first register via ca...
# 2   first week bounty campaign start signature dis...
# 3
# 4
# 8
# 9   necessary join telegram main chat bounty chat ...
# 10
# 11
# 13
# 14             start working translation get approval
# 15
# 16
# 17  account must least old least must include must...
# 18
# 20
# 21
# 22
# 23
# 25  list per week simply register participation co...
# 26
# 28
# 29
# 30  content must original unique relevant article ...
# 31
# 33  need visit official get familiarize project mu...
# 35  least member every participant must wear signa...
# 36
# 37
# 38
# 40
# 41
# 43
# 44
# 46
# 49
#
#                                         combined_text
# 1   project bounty thread bounty campaign official...
# 2   bounty th week everyone team decided end bount...
# 3   campaign magic pool new campaign magic join ro...
# 4   reserved phase reserved available bounty amoun...
# 8   feedback bounty place responsible bounty power...
# 9   economy image longer protocol layer designed h...
# 10  education training celebrate launch education ...
# 11  new exchange platform official main thread tru...
# 13  would like join program new understand much te...
# 14  translation community present following twitte...
# 15  development k ell reward see bounty final repo...
# 16  amazing airdrop everyone post bounty phase bou...
# 17  k worth token reward democratic marketing comp...
# 18  available join massive bonus topic giveaway po...
# 20  airdrop made falsely urge see accusation threa...
# 21  token first based index time ago team looking ...
# 22  exchange sure market today promise project dec...
# 23  earth first earth token earth increase global ...
# 25  hash rush game signature translation campaign ...
# 26  airdrop automatic trading robot worth airdrop ...
# 28  coin conference article global coin conference...
# 29  distributed tech community tech upon business ...
# 30   bounty telegram thread token sale affiliate p...
# 31  join pixie token bounty airdrop portal image l...
# 33  telegram bounty day budget token n r bounty ca...
# 35   note every must join official telegram group ...
# 36     bounty bounty already trade prove claim bounty
# 37  trading simplified maximum daily bounty game g...
# 38  network twitter ann thread medium mention tele...
# 40  airdrop join telegram earn airdrop campaign tw...
# 41  marquise museum debit card partnership project...
# 43  round free weekly draw member eligible least m...
# 44  digital magazine platform bounty token st th d...
# 46  bounty program content referral social every f...
# 49  remove network thank participation late airdro...
#
# [35 rows x 37 columns]
